# %%
using LinearAlgebra
using Base

# %%
import Base: +, *, -, ^, exp

# %%
dot(step(range(0,1,length=100)) * [.5; ones(length(range(0,1,length=100))-2);.5], range(0,1,length=100).^2)
# Out:
# 0.3333503384008434

# %%
struct Weights
    r::StepRangeLen
end

Base.iterate(W::Weights, state=1) = state > length(W.r) ? nothing : ((step(W.r) * [.5 ones(length(W.r)-2)... .5])[state], state+1)
Base.size(W::Weights) = length(W.r)
Base.IndexStyle(::Type{<:StepRangeLen}) = IndexLinear()
Base.getindex(W::Weights, i::Int) = W.r[i]

# %%
dot(Weights(range(0,1,length=100)), range(0,1,length=100).^2)
# Out:
# 0.3333503384008434

# %%
using Pkg
#Pkg.add("ForwardDiff")
using ForwardDiff
# Out:
#    Resolving package versions...
#    Installed IrrationalConstants ── v0.1.0
#    Installed OpenSpecFun_jll ────── v0.5.5+0
#    Installed DiffResults ────────── v1.0.3
#    Installed CommonSubexpressions ─ v0.3.0
#    Installed LogExpFunctions ────── v0.3.2
#    Installed SpecialFunctions ───── v1.6.1
#    Installed ForwardDiff ────────── v0.10.19
#    Installed ChainRulesCore ─────── v1.4.0
#    Installed DiffRules ──────────── v1.3.0
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [f6369f11] + ForwardDiff v0.10.19
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [d360d2e6] + ChainRulesCore v1.4.0
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [163ba53b] + DiffResults v1.0.3
#   [b552c78f] + DiffRules v1.3.0
#   [f6369f11] + ForwardDiff v0.10.19
#   [92d709cd] + IrrationalConstants v0.1.0
#   [2ab3a3ac] + LogExpFunctions v0.3.2
#   [276daf66] + SpecialFunctions v1.6.1
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
# Precompiling project...
#   ✓ IrrationalConstants
#   ✓ CommonSubexpressions
#   ✓ ChainRulesCore
#   ✓ OpenSpecFun_jll
#   ✓ DiffResults
#   ✓ LogExpFunctions
#   ✓ SpecialFunctions
#   ✓ DiffRules
#   ✓ ForwardDiff
#   9 dependencies successfully precompiled in 22 seconds (148 already precompiled)

# %%
struct DualNumber{T} <: Real
    val::T
    ϵ::T
end

# %%
+(x::DualNumber, y::DualNumber) = DualNumber(x.val + y.val, x.ϵ + y.ϵ)  # dual addition
+(x::DualNumber, a::Number) = DualNumber(x.val + a, x.ϵ)  # i.e. scalar addition, not dual
+(a::Number, x::DualNumber) = DualNumber(x.val + a, x.ϵ)  # i.e. scalar addition, not dual
# Out:
# + (generic function with 193 methods)

# %%
-(x::DualNumber, y::DualNumber) = DualNumber(x.val - y.val, x.ϵ - y.ϵ)  # dual addition
-(x::DualNumber, a::Number) = DualNumber(x.val - a, x.ϵ)  # i.e. scalar addition, not dual
-(a::Number, x::DualNumber) = DualNumber(x.val - a, x.ϵ)  # i.e. scalar addition, not dual
# Out:
# - (generic function with 200 methods)

# %%
*(x::DualNumber, y::DualNumber) = DualNumber(x.val * y.val, x.val * y.ϵ + x.val * x.ϵ)  # dual addition
*(x::DualNumber, a::Number) = #DualNumber(x.val - a, x.ϵ)  # i.e. scalar addition, not dual
*(a::Number, x::DualNumber) = #DualNumber(x.val - a, x.ϵ)  # i.e. scalar addition, not dual

# %%
f(x, y) = 3.0 + x + y

x = DualNumber(2.0, 1.0)
y = DualNumber(3.0, 0.0)

f(x,y)
# Out:
# DualNumber{Float64}(8.0, 1.0)

# %%
f(x,y) = 3 - x - y
y = DualNumber(3,15)
f(x,y)
# Out:
# DualNumber{Float64}(-4.0, -14.0)
